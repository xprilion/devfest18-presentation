# %%
import numpy as np
import pandas as pd
import nltk
from nltk.stem.snowball import SnowballStemmer
from bs4 import BeautifulSoup
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3

# %% [markdown]
# Read movie titles, 100 movies; the last one is empty string

# %%
titles = open('data/title_list.txt').read().split('\n')

# %%
len(titles)
# Out:
# 101

# %%
titles[:10]
# Out:
# ['The Godfather',
#  'The Shawshank Redemption',
#  "Schindler's List",
#  'Raging Bull',
#  'Casablanca',
#  "One Flew Over the Cuckoo's Nest",
#  'Gone with the Wind',
#  'Citizen Kane',
#  'The Wizard of Oz',
#  'Titanic']

# %%
titles = titles[:100]
# Just turning it around

# %% [markdown]
# Read Genres information

# %%
genres = open('data/genres_list.txt').read().split('\n')
genres = genres[:100]

# %%
genres[0]
# Out:
# "[u' Crime', u' Drama']"

# %% [markdown]
# Read in the synopses from wiki

# %%
synopses_wiki = open('data/synopses_list_wiki.txt').read().split('\n BREAKS HERE')

# %%
len(synopses_wiki)
# Out:
# 101

# %%
synopses_wiki = synopses_wiki[:100]

# %%
#synopses_wiki[0]

# %% [markdown]
# strips html formatting and converts to unicode

# %%
synopses_clean_wiki = []
for text in synopses_wiki:
    text = BeautifulSoup(text, 'html.parser').getText()
    synopses_clean_wiki.append(text)
synopses_wiki = synopses_clean_wiki

# %%
#synopses_wiki[0]

# %% [markdown]
# Read synopses information from imdb, which might be different from wiki. Also cleaned as above.

# %%
synopses_imdb = open('data/synopses_list_imdb.txt').read().split('\n BREAKS HERE')
synopses_imdb = synopses_imdb[:100]

synopses_clean_imdb = []

for text in synopses_imdb:
    text = BeautifulSoup(text, 'html.parser').getText()
    synopses_clean_imdb.append(text)
synopses_imdb = synopses_clean_imdb

# %%
#synopses_imdb[0]

# %% [markdown]
# Combine synopses from wiki and imdb

# %%
synopses = []
for i in range(len(synopses_wiki)):
    item = synopses_wiki[i] + synopses_imdb[i]
    synopses.append(item)

# %%
#synopses[0]

# %%
print(str(len(titles)) + ' titles')
print(str(len(genres)) + ' genres')
print(str(len(synopses)) + ' synopses')
# Out:
# 100 titles
# 100 genres
# 100 synopses

# %%
# generates index for each item in the corpora (in this case it's just rank) and I'll use this for scoring later
# the movies in the list are already ranked from 1 to 100
ranks = []
for i in range(1, len(titles)+1):
    ranks.append(i)

# %% [markdown]
# # Start Code Here

# %%
# load nltk's English stopwords as variable called 'stopwords'
# use nltk.download() to install the corpus first
# Stop Words are words which do not contain important significance to be used in Search Queries

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# load nltk's SnowballStemmer as variabled 'stemmer'

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# %%
len(stopwords)
# Out:
# 179

# %%
#stopwords

# %%
# sents = [sent for sent in nltk.sent_tokenize("Today (May 19, 2016) is his only daughter's wedding. Vito Corleone is the Godfather. Vito's youngest son, Michael, in a Marine Corps uniform, introduces his girlfriend, Kay Adams, to his family at the sprawling reception.")]

# %%
# Tokenize documents into sentences

#Create a variable 'sents' which is a list of strings obtained by tokenizing the string below:
'''
Today (May 19, 2016) is his only daughter's wedding. Vito Corleone is the Godfather. Vito's youngest son, Michael, in a Marine Corps uniform, introduces his girlfriend, Kay Adams, to his family at the sprawling reception.
'''

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# %%
sents
# Out:
# ["Today (May 19, 2016) is his only daughter's wedding.",
#  'Vito Corleone is the Godfather.',
#  "Vito's youngest son, Michael, in a Marine Corps uniform, introduces his girlfriend, Kay Adams, to his family at the sprawling reception."]

# %%
# Tokenize sentences into words

#Create a variable 'words' which is a list of strings obtained by tokenizing the first string in sents 

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# %%
words
# Out:
# ['Today',
#  '(',
#  'May',
#  '19',
#  ',',
#  '2016',
#  ')',
#  'is',
#  'his',
#  'only',
#  'daughter',
#  "'s",
#  'wedding',
#  '.']

# %%
# filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
filtered_words = []
for word in words:
        if re.search('[a-zA-Z]', word):
            filtered_words.append(word)
filtered_words
# Out:
# ['Today', 'May', 'is', 'his', 'only', 'daughter', "'s", 'wedding']

# %%
# Stem words 

#Create a variable 'stems' which is a list of stemmed words obtained by stemming filtered_words

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# %%
# see how "only" is stemmed to "onli" and "wedding" is stemmed to "wed"
stems
# Out:
# ['today', 'may', 'is', 'his', 'onli', 'daughter', "'s", 'wed']

# %% [markdown]
# ### Pause Code Here

# %%
# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed
# Punkt Sentence Tokenizer, sent means sentence 
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

# %%
def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
words_stemmed = tokenize_and_stem("Today (May 19, 2016) is his only daughter's wedding.")
print(words_stemmed)
# Out:
# ['today', 'may', 'is', 'his', 'onli', 'daughter', "'s", 'wed']

# %%
words_only = tokenize_only("Today (May 19, 2016) is his only daughter's wedding.")
words_only
# Out:
# ['today', 'may', 'is', 'his', 'only', 'daughter', "'s", 'wedding']

# %% [markdown]
# Below I use my stemming/tokenizing and tokenizing functions to iterate over the list of synopses to create two vocabularies: one stemmed and one only tokenized

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in synopses:
    allwords_stemmed = tokenize_and_stem(i) # for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) # extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
print(len(totalvocab_stemmed))
print(len(totalvocab_tokenized))
# Out:
# 312301
# 312301

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
print(vocab_frame.head())
# Out:
# there are 312301 items in vocab_frame
#      words
# plot  plot
# edit  edit
# edit  edit
# edit  edit
# on      on

# %% [markdown]
# ### Resume Code Here

# %% [markdown]
# Generate TF-IDF matrix (see http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html)

# %%
# Note that the result of this block takes a while to show

#Import TfidfVectorizer from sklearn.feature_extraction.text

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

from sklearn.feature_extraction.text import TfidfVectorizer

#define vectorizer parameters

# Create a TfidfVectorizer named tfidf_vectorizer with the below configuration

##########   CODE BELOW    ##########

_____________ = ______________(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=_____, _____)

##########   CODE ABOVE    ##########


#fit transform synopses to tfidf_vectorizer and store as tfidf_matrix

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# (100, 563) means the matrix has 100 rows and 563 columns
print(tfidf_matrix.shape)
terms = tfidf_vectorizer.get_feature_names()
len(terms)
# Out:
# CPU times: user 13.2 s, sys: 56.1 ms, total: 13.3 s
# Wall time: 13.4 s
# (100, 563)
# 563

# %% [markdown]
# Now onto the fun part. Using the tf-idf matrix, you can run a slew of clustering algorithms to better understand the hidden structure within the synopses. I first chose k-means. K-means initializes with a pre-determined number of clusters (I chose 5). Each observation is assigned to a cluster (cluster assignment) so as to minimize the within cluster sum of squares. Next, the mean of the clustered observations is calculated and used as the new cluster centroid. Then, observations are reassigned to clusters and centroids recalculated in an iterative process until the algorithm reaches convergence.
#
# I found it took several runs for the algorithm to converge a global optimum as k-means is susceptible to reaching local optima - how to decide that the algorithm converged???

# %%
#import KMeans from sklearn.cluster
#create KMeans object km with n_clusters = 5

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

#fit tfidf_matrix to km 

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

clusters = km.labels_.tolist()
# Out:
# CPU times: user 832 ms, sys: 4 µs, total: 832 ms
# Wall time: 840 ms

# %% [markdown]
# ### Pause Code Here

# %% [markdown]
# Here, I create a dictionary of titles, ranks, the synopsis, the cluster assignment, and the genre [rank and genre were scraped from IMDB].
# I convert this dictionary to a Pandas DataFrame for easy access. I'm a huge fan of Pandas and recommend taking a look at some of its awesome functionality which I'll use below, but not describe in a ton of detail.

# %%
films = { 'title': titles, 'rank': ranks, 'synopsis': synopses, 'cluster': clusters, 'genre': genres }

frame = pd.DataFrame(films, index = [clusters] , columns = ['rank', 'title', 'cluster', 'genre'])

print(frame) # here the ranking is still 0 to 99

frame['cluster'].value_counts() #number of films per cluster (clusters from 0 to 4)
# Out:
#     rank                                              title  cluster  \
# 1      1                                      The Godfather        1
# 2      2                           The Shawshank Redemption        2
# 2      3                                   Schindler's List        2
# 4      4                                        Raging Bull        4
# 2      5                                         Casablanca        2
# 2      6                    One Flew Over the Cuckoo's Nest        2
# 1      7                                 Gone with the Wind        1
# 4      8                                       Citizen Kane        4
# 1      9                                   The Wizard of Oz        1
# 1     10                                            Titanic        1
# 2     11                                 Lawrence of Arabia        2
# 4     12                             The Godfather: Part II        4
# 1     13                                             Psycho        1
# 1     14                                       Sunset Blvd.        1
# 1     15                                            Vertigo        1
# 4     16                                  On the Waterfront        4
# 1     17                                       Forrest Gump        1
# 0     18                                 The Sound of Music        0
# 1     19                                    West Side Story        1
# 2     20                                          Star Wars        2
# 1     21                         E.T. the Extra-Terrestrial        1
# 4     22                              2001: A Space Odyssey        4
# 1     23                           The Silence of the Lambs        1
# 4     24                                          Chinatown        4
# 2     25                       The Bridge on the River Kwai        2
# 0     26                                Singin' in the Rain        0
# 3     27                              It's a Wonderful Life        3
# 1     28                                   Some Like It Hot        1
# 4     29                                       12 Angry Men        4
# 2     30  Dr. Strangelove or: How I Learned to Stop Worr...        2
# ..   ...                                                ...      ...
# 1     71                                           Rain Man        1
# 4     72                                         Annie Hall        4
# 1     73                                      Out of Africa        1
# 1     74                                  Good Will Hunting        1
# 1     75                                Terms of Endearment        1
# 3     76                                            Tootsie        3
# 1     77                                              Fargo        1
# 1     78                                              Giant        1
# 1     79                                The Grapes of Wrath        1
# 4     80                                              Shane        4
# 2     81                                     The Green Mile        2
# 1     82                 Close Encounters of the Third Kind        1
# 4     83                                            Network        4
# 0     84                                          Nashville        0
# 1     85                                       The Graduate        1
# 1     86                                  American Graffiti        1
# 1     87                                       Pulp Fiction        1
# 4     88                                  The African Queen        4
# 2     89                                         Stagecoach        2
# 4     90                               Mutiny on the Bounty        4
# 1     91                                 The Maltese Falcon        1
# 1     92                                 A Clockwork Orange        1
# 4     93                                        Taxi Driver        4
# 1     94                                  Wuthering Heights        1
# 1     95                                   Double Indemnity        1
# 1     96                              Rebel Without a Cause        1
# 1     97                                        Rear Window        1
# 1     98                                      The Third Man        1
# 1     99                                 North by Northwest        1
# 0    100                                Yankee Doodle Dandy        0
#
#                                                 genre
# 1                              [u' Crime', u' Drama']
# 2                              [u' Crime', u' Drama']
# 2             [u' Biography', u' Drama', u' History']
# 4               [u' Biography', u' Drama', u' Sport']
# 2                   [u' Drama', u' Romance', u' War']
# 2                                         [u' Drama']
# 1                   [u' Drama', u' Romance', u' War']
# 4                            [u' Drama', u' Mystery']
# 1   [u' Adventure', u' Family', u' Fantasy', u' Mu...
# 1                            [u' Drama', u' Romance']
# 2   [u' Adventure', u' Biography', u' Drama', u' H...
# 4                              [u' Crime', u' Drama']
# 1             [u' Horror', u' Mystery', u' Thriller']
# 1                          [u' Drama', u' Film-Noir']
# 1            [u' Mystery', u' Romance', u' Thriller']
# 4                              [u' Crime', u' Drama']
# 1                            [u' Drama', u' Romance']
# 0   [u' Biography', u' Drama', u' Family', u' Musi...
# 1   [u' Crime', u' Drama', u' Musical', u' Romance...
# 2   [u' Action', u' Adventure', u' Fantasy', u' Sc...
# 1             [u' Adventure', u' Family', u' Sci-Fi']
# 4                           [u' Mystery', u' Sci-Fi']
# 1                [u' Crime', u' Drama', u' Thriller']
# 4              [u' Drama', u' Mystery', u' Thriller']
# 2                 [u' Adventure', u' Drama', u' War']
# 0              [u' Comedy', u' Musical', u' Romance']
# 3                [u' Drama', u' Family', u' Fantasy']
# 1                                        [u' Comedy']
# 4                                         [u' Drama']
# 2                               [u' Comedy', u' War']
# ..                                                ...
# 1                                         [u' Drama']
# 4                [u' Comedy', u' Drama', u' Romance']
# 1             [u' Biography', u' Drama', u' Romance']
# 1                                         [u' Drama']
# 1                             [u' Comedy', u' Drama']
# 3                [u' Comedy', u' Drama', u' Romance']
# 1                [u' Crime', u' Drama', u' Thriller']
# 1                            [u' Drama', u' Romance']
# 1                                         [u' Drama']
# 4               [u' Drama', u' Romance', u' Western']
# 2    [u' Crime', u' Drama', u' Fantasy', u' Mystery']
# 1                             [u' Drama', u' Sci-Fi']
# 4                                         [u' Drama']
# 0                              [u' Drama', u' Music']
# 1                [u' Comedy', u' Drama', u' Romance']
# 1                             [u' Comedy', u' Drama']
# 1                [u' Crime', u' Drama', u' Thriller']
# 4               [u' Adventure', u' Romance', u' War']
# 2                        [u' Adventure', u' Western']
# 4             [u' Adventure', u' Drama', u' History']
# 1             [u' Drama', u' Film-Noir', u' Mystery']
# 1                  [u' Crime', u' Drama', u' Sci-Fi']
# 4                              [u' Crime', u' Drama']
# 1                            [u' Drama', u' Romance']
# 1   [u' Crime', u' Drama', u' Film-Noir', u' Thril...
# 1                                         [u' Drama']
# 1                         [u' Mystery', u' Thriller']
# 1          [u' Film-Noir', u' Mystery', u' Thriller']
# 1                         [u' Mystery', u' Thriller']
# 0             [u' Biography', u' Drama', u' Musical']
#
# [100 rows x 4 columns]
# 1    43
# 4    24
# 2    22
# 3     6
# 0     5
# Name: cluster, dtype: int64

# %% [markdown]
# Note that clusters 4 and 0 have the lowest rank, which indicates that they, on average, contain films that were ranked as "better" on the top 100 list.
# Here is some fancy indexing and sorting on each cluster to identify which are the top n (I chose n=6) words that are nearest to the cluster centroid. This gives a good sense of the main topic of the cluster.

# %%
print("Top terms per cluster:")

#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        print(' %s' % vocab_frame.loc[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d titles:" % i, end='')
    for title in frame.loc[i]['title'].values.tolist():
        print(' %s,' % title, end='')
    print() #add whitespace
    print() #add whitespace
# Out:
# Top terms per cluster:
# Cluster 0 words: b'singing', b'perform', b'music', b'captain', b'film', b'dance',
#
# Cluster 0 titles: The Sound of Music, Singin' in the Rain, Amadeus, Nashville, Yankee Doodle Dandy,
#
# Cluster 1 words: b'car', b'police', b'home', b'family', b'house', b'mother',
#
# Cluster 1 titles: The Godfather, Gone with the Wind, The Wizard of Oz, Titanic, Psycho, Sunset Blvd., Vertigo, Forrest Gump, West Side Story, E.T. the Extra-Terrestrial, The Silence of the Lambs, Some Like It Hot, Gandhi, Rocky, A Streetcar Named Desire, The Best Years of Our Lives, My Fair Lady, Ben-Hur, Goodfellas, The Exorcist, The French Connection, It Happened One Night, Midnight Cowboy, Mr. Smith Goes to Washington, Rain Man, Out of Africa, Good Will Hunting, Terms of Endearment, Fargo, Giant, The Grapes of Wrath, Close Encounters of the Third Kind, The Graduate, American Graffiti, Pulp Fiction, The Maltese Falcon, A Clockwork Orange, Wuthering Heights, Double Indemnity, Rebel Without a Cause, Rear Window, The Third Man, North by Northwest,
#
# Cluster 2 words: b'soldiers', b'army', b'war', b'command', b'killed', b'orders',
#
# Cluster 2 titles: The Shawshank Redemption, Schindler's List, Casablanca, One Flew Over the Cuckoo's Nest, Lawrence of Arabia, Star Wars, The Bridge on the River Kwai, Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Apocalypse Now, Gladiator, From Here to Eternity, Saving Private Ryan, Raiders of the Lost Ark, Doctor Zhivago, Patton, Platoon, Dances with Wolves, The Pianist, The Deer Hunter, All Quiet on the Western Front, The Green Mile, Stagecoach,
#
# Cluster 3 words: b'george', b'marries', b'woman', b'family', b'friends', b'john',
#
# Cluster 3 titles: It's a Wonderful Life, The Philadelphia Story, An American in Paris, The King's Speech, A Place in the Sun, Tootsie,
#
# Cluster 4 words: b'killed', b'water', b'new', b'town', b'father', b'york',
#
# Cluster 4 titles: Raging Bull, Citizen Kane, The Godfather: Part II, On the Waterfront, 2001: A Space Odyssey, Chinatown, 12 Angry Men, The Lord of the Rings: The Return of the King, Unforgiven, To Kill a Mockingbird, Jaws, Braveheart, The Good, the Bad and the Ugly, Butch Cassidy and the Sundance Kid, The Treasure of the Sierra Madre, The Apartment, High Noon, City Lights, Annie Hall, Shane, Network, The African Queen, Mutiny on the Bounty, Taxi Driver,

# %% [markdown]
# ### Resume Code Here

# %% [markdown]
# Cosine similarity is measured against the tf-idf matrix and can be used to generate a measure of similarity between each document and the other documents in the corpus (each synopsis among the synopses). cosine similarity 1 means the same document, 0 means totally different ones. dist is defined as 1 - the cosine similarity of each document.  Subtracting it from 1 provides cosine distance which I will use for plotting on a euclidean (2-dimensional) plane.
# Note that with dist it is possible to evaluate the similarity of any two or more synopses.

# %%
#import cosine_similarity from sklearn.metrics.pairwise
#calculate similarity_distance as 1 - cosine_similarity

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########
# Out:
# <class 'numpy.ndarray'>
# (100, 100)

# %%
#import matplotlib.pyplot as plt and configure it to output inline

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# %%
#import linkage and dendrogram from scipy.cluster.hierarchy

##########   CODE BELOW    ##########

##########   CODE ABOVE    ##########

# %%
#create mergings as an linkage object over similarity_distance.

##########   CODE BELOW    ##########

mergings = _______(______, method='complete')

# Plot the dendrogram, using titles as labels
dendrogram(mergings,
           labels=_____,
           leaf_rotation=90,
           leaf_font_size=16,
)

##########   CODE ABOVE    ##########

fig = plt.gcf()
fig.set_size_inches(108, 21)

plt.show()

# %% [markdown]
# # That's All Fox!
